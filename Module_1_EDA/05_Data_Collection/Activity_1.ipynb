# %%
# Q. From Quotes, extract all the quotes and authors from all pages with life tag

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# as there are too many pages on the website, to fetch it we will use loop

page_count = 1 

while True:
    URL = f"https://quotes.toscrape.com/page/{page_count}/"
    response = requests.get(URL)

    soup = BeautifulSoup(response.text,"lxml")
    quotes = soup.select("div.quote")

    if not quotes:
        print("cannot fetch data, empty page")
        break

    with open(f"Scraped_data/quotes_{page_count}.html","w") as f:
        f.write(response.text)
        print(f"data download from page {page_count}")

    page_count = page_count + 1
# Out:
# data download from page 1
# data download from page 2
# data download from page 3
# data download from page 4
# data download from page 5
# data download from page 6
# data download from page 7
# data download from page 8
# data download from page 9
# data download from page 10
# cannot fetch data, empty page

# %%
# now as data is downloaded, we can start scraping the useful contents

count = 1

while count < 11:
    
    with open(f"Scraped_data/quotes_{count}.html","r") as f:
        html_content = f.read()
    
    soup = BeautifulSoup(html_content,"lxml")
    
    all_quotes = soup.select("div.quote")
    life_quotes = []
    
    for q in all_quotes:
        
        all_tags = []
        for tag in q.select("div.tags .tag"):
            all_tags.append(tag.get_text())
    
        
        if "life" in all_tags:
            text = q.select_one("span.text").get_text()
            author = q.select_one("small.author").get_text()
            life_quotes.append([text,author])

    df = pd.DataFrame(life_quotes, columns = ["Quote","Author"])
    df.to_csv(f"Cleaned_data/quotes_{count}.csv", index=False)
    print(f"data cleaned and stored as quotes_{count}.csv")

    count = count + 1
# Out:
# data cleaned and stored as quotes_1.csv
# data cleaned and stored as quotes_2.csv
# data cleaned and stored as quotes_3.csv
# data cleaned and stored as quotes_4.csv
# data cleaned and stored as quotes_5.csv
# data cleaned and stored as quotes_6.csv
# data cleaned and stored as quotes_7.csv
# data cleaned and stored as quotes_8.csv
# data cleaned and stored as quotes_9.csv
# data cleaned and stored as quotes_10.csv
