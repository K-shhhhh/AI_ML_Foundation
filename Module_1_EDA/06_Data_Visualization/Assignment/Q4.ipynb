# %% [markdown]
# ### Q4. For the Seaborn tips dataset, do the following:
# - Create a scatter plot of total_bill vs tip
# - Color points by sex
# - Use different markers for smoker
# - Add a title and axis labels
# - Analyze: Do smokers tend to tip differently?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="ticks")

tips = sns.load_dataset("tips")
tips.head()

sns.scatterplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="sex",
    style="smoker",   
)

plt.title("Scatter Plot for Tips and Bills paid")
plt.xlabel("Bill")
plt.ylabel("Tip")
plt.grid(True)
plt.tight_layout()

# Non-Smokers (Consistent): They have a very tight, predictable linear trend. As their bill goes up, their tip goes up at a steady, standard percentage rate.
# Smokers (High Variance): They are wild cards. When the bills get large (above 30 dollars), smokers either tip massively high (well above the normal line) or drop down and tip incredibly low.
