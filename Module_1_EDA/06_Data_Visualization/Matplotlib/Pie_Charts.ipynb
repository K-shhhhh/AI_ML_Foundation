# %% [markdown]
# ## Circular chart divided into slices to show relative proportions of a whole
# - each slice = a category
# - size of slice = value of that category relative of total
# - prefer them only when there are a few categories

# %%
import matplotlib.pyplot as plt

expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]

# plt.pie(amounts, labels = expenses) # first we plot the numbers/values, then we label them accordingly
plt.style.available # shows all the available styles
plt.style.use("default") # uses the actual style

# customizations

# Q. show % of each category in the pie chart
# plt.pie(amounts, labels = expenses, autopct="%.2f%%")

# Q. add a list of colors as customized colors in the pie chart
colors = ["red", "blue", "green", "violet", "orange"]
# plt.pie(amounts, labels=expenses, autopct = "%.2f%%", colors = colors)

# Q. use wedge function to customize the properties of the pie chart 
# plt.pie(amounts, labels=expenses, autopct="%.2f%%",
#        wedgeprops={
#            "alpha" : 0.5, # transparency
#            "edgecolor" : "black", # color of each edge of the slice of the pie chart
#            "linewidth" : 1, # width of the edges
#            "linestyle" : "--", # style of the edges
#            "fill" : False # has the power to take away all the colors of our pie chart
           
#            # we can find more wedge properties on matplotlib.org

# })  


# Q. Highlight the R&D slice out of the pie chart
explode = [0 ,0 ,0 ,0.2 , 0] # list where we specifically want to highlight R&D category
# plt.pie(amounts, labels=expenses,autopct="%.2f%%", explode = explode) # pass the list to explode function

# Q. Rotate the default pie chart by 90 degrees
# plt.pie(amounts, labels=expenses,autopct="%.2f%%",startangle=90)

# q. give a 3d effect on the pie chart
plt.pie(amounts, labels=expenses,autopct="%.2f%%",shadow=True)

plt.show()
